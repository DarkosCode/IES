# %% [markdown]
# ## Iteradores e iterables

# %% [markdown]
# 10) A partir de la variable cadena ya dada, mostrar en qué posiciones aparece la letra "n"<br>
# cadena = 'Hola Mundo. Esto es una practica del lenguaje de programación Python'

# %%
cadena = "Hola Mundo. Esto es una practica del lenguaje de programacion Python"
for c, i in enumerate(cadena):
    if i == "n":
        print(c, i)
# Out:
# 7 n
# 21 n
# 39 n
# 60 n
# 67 n

# %% [markdown]
# 11) Crear un diccionario e imprimir sus claves utilizando un iterador

# %%
diccionario = {"c1": 1, "c2": 2, "c3": 3}
for p in diccionario:
    print(p)
# Out:
# c1
# c2
# c3

# %% [markdown]
# 12) Crear dos listas y unirlas en una tupla utilizando la función zip

# %%
listaUno = ["River", "Boca", "Racing", "Independiente", "San Lorenzo"]
dosLista = ["Acuña", "Paredes", "Rojas", "Avalos", "Romaña"]
zipeada = zip(listaUno, dosLista)
print(zipeada) #? no se imprimen los elementos de dentro
print(list(zipeada))
# Out:
# ...
# [('River', 'Acuña'), ('Boca', 'Paredes'), ('Racing', 'Rojas'), ('Independiente', 'Avalos'), ('San Lorenzo', 'Romaña')]

# %% [markdown]
# 13) A partir de la siguiente lista de números, crear una nueva sólo si el número es divisible por 7<br>
# lis = [18,21,29,32,35,42,56,60,63,71,84,90,91,100]

# %%
lis = [18,21,29,32,35,42,56,60,63,71,84,90,91,100]
# newlist = []
# for n in lis:
#     if n % 7 == 0:
#         newlist.append(n)
# print(newlist)

nueva = [t for t in lis if t % 7 == 0]
print(nueva)
# Out:
# [21, 35, 42, 56, 63, 84, 91]

# %% [markdown]
# 14) A partir de la lista de a continuación, contar la cantidad total de elementos que contiene, teniendo en cuenta que un elemento de la lista podría ser otra lista:<br>
# lis = [[1,2,3,4],'rojo','verde',[True,False,False],['uno','dos','tres']]

# %%
lis = [[1,2,3,4],'rojo','verde',[True,False,False],['uno','dos','tres']]
Contelemen = 0
for i in lis:
    if isinstance(i, (list)): #* verifica si es de tipo lista
    # if type(i) == list:
        for l in i:
            Contelemen += 1
    else:
        Contelemen += 1
print(Contelemen)
# Out:
# 12

# %% [markdown]
# 15) Tomar la lista del punto anterior y convertir cada elemento en una lista si no lo es

# %%
for i, e in enumerate (lis):
    if not isinstance(e, (list)):
        lis[i] = [e]

for elemento in lis:
    print(f"{elemento} - {type(elemento)}")
# Out:
# [1, 2, 3, 4] - <class 'list'>
# ['rojo'] - <class 'list'>
# ['verde'] - <class 'list'>
# [True, False, False] - <class 'list'>
# ['uno', 'dos', 'tres'] - <class 'list'>
